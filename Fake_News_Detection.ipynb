# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanbarde80/maching_learning/blob/main/Fake_News_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')

# %%
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true['label'] = 1

# %%
fake['label'] = 0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = pd.concat([fake, true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1) #Reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 4865   WASHINGTON (Reuters) - The Trump administratio...      1
# 11385  With a growing number of Muslim refugees and i...      0
# 16808  SITTWE, Myanmar (Reuters) - Rohingya Muslims w...      1
# 9894   WASHINGTON (Reuters) - Paul Ryan, the Speaker ...      1
# 23453  21st Century Wire says Most people accept that...      0

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   4865  WASHINGTON (Reuters) - The Trump administratio...      1
# 1  11385  With a growing number of Muslim refugees and i...      0
# 2  16808  SITTWE, Myanmar (Reuters) - Rohingya Muslims w...      1
# 3   9894  WASHINGTON (Reuters) - Paul Ryan, the Speaker ...      1
# 4  23453  21st Century Wire says Most people accept that...      0

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    level_0  index                                               text  label
# 0        0   4865  WASHINGTON (Reuters) - The Trump administratio...      1
# 1        1  11385  With a growing number of Muslim refugees and i...      0
# 2        2  16808  SITTWE, Myanmar (Reuters) - Rohingya Muslims w...      1
# 3        3   9894  WASHINGTON (Reuters) - Paul Ryan, the Speaker ...      1
# 4        4  23453  21st Century Wire says Most people accept that...      0

# %%
news.drop(['index'],axis=1,inplace=True)

# %%
news.head()
# Out:
#    level_0                                               text  label
# 0        0  WASHINGTON (Reuters) - The Trump administratio...      1
# 1        1  With a growing number of Muslim refugees and i...      0
# 2        2  SITTWE, Myanmar (Reuters) - Rohingya Muslims w...      1
# 3        3  WASHINGTON (Reuters) - Paul Ryan, the Speaker ...      1
# 4        4  21st Century Wire says Most people accept that...      0

# %%
news.drop(['index'], axis=1, inplace=True, errors='ignore')

# %%
news.head()
# Out:
#    level_0                                               text  label
# 0        0  WASHINGTON (Reuters) - The Trump administratio...      1
# 1        1  With a growing number of Muslim refugees and i...      0
# 2        2  SITTWE, Myanmar (Reuters) - Rohingya Muslims w...      1
# 3        3  WASHINGTON (Reuters) - Paul Ryan, the Speaker ...      1
# 4        4  21st Century Wire says Most people accept that...      0

# %%
import re # regex in python

# %%
def wordopt(text):
  # convert to lowercase
  text = text.lower()

  # remove url's
  text = re.sub(r'https?://\S+|www\.\S+', '', text)

  # remove html tags
  text = re.sub(r'<.*?>','',text)

  # remove punctuation
  text = re.sub(r'[^\w\s]','',text)

  # remove digits
  text = re.sub(r'\d','',text)

  # remove newline characters
  text = re.sub(r'\n',' ',text)

  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        washington reuters  the trump administration t...
# 1        with a growing number of muslim refugees and i...
# 2        sittwe myanmar reuters  rohingya muslims who r...
# 3        washington reuters  paul ryan the speaker of t...
# 4        st century wire says most people accept that a...
#                                ...
# 44893    chris cuomo of fake news network cnn interview...
# 44894    ted cruz provided a funny moment during the re...
# 44895    on new jersey  chris christie made the argumen...
# 44896    students in idaho are one vote away from havin...
# 44897    johannesburg reuters  south africa s ruling af...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x175060 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6452404 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x175060 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2728099 stored elements in Compressed Sparse Row format>

# %%
# using some ml algorithm

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9887899034892353

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6962
#            1       0.99      0.99      0.99      6508
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
# other algo application

# %%
# decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)
# Out:
# 0.9958426132145508

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6962
#            1       1.00      1.00      1.00      6508
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
# random forest classifier
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test,y_test)
# Out:
# 0.9893095768374165

# %%
print(classification_report(y_test, predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6962
#            1       0.99      0.99      0.99      6508
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test,y_test)
# Out:
# 0.9942093541202672

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      6962
#            1       0.99      1.00      0.99      6508
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
# building predictive model now

# %%
def output_label(n):
  if n == 0:
    return "It is a Fake News"
  elif n == 1:
    return "It is a Genuine News"

# %%
def manual_testing(news):
  testing_news = {"text":[news]}
  new_def_test = pd.DataFrame(testing_news)
  new_def_test["text"] = new_def_test["text"].apply(wordopt)
  new_x_test = new_def_test["text"]
  new_xv_test = vectorization.transform(new_x_test)
  pred_lr = LR.predict(new_xv_test)
  # pred_dtc = DTC.predict(new_xv_test)
  pred_gbc = gbc.predict(new_xv_test)
  pred_rfc = rfc.predict(new_xv_test)
  return print("\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(output_label(pred_lr), output_label(pred_gbc), output_label(pred_rfc)))

# %%
news_article = str(input())
